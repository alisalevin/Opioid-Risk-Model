# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
opioids = pd.read_csv('opioid_data.csv')

# %%
# Separate Data into 5 States
ohio = opioids.loc[opioids['State'] == 'OH']
virginia = opioids.loc[opioids['State'] == 'VA']
kentucky = opioids.loc[opioids['State'] == 'KY']
pennsylvania = opioids.loc[opioids['State'] == 'PA']
west_virginia = opioids.loc[opioids['State'] == 'WV']

# %%
# Separate Ohio by Year
ohio_10 = ohio.loc[ohio['YYYY'] == 2010]
ohio_11 = ohio.loc[ohio['YYYY'] == 2011]
ohio_12 = ohio.loc[ohio['YYYY'] == 2012]
ohio_13 = ohio.loc[ohio['YYYY'] == 2013]
ohio_14 = ohio.loc[ohio['YYYY'] == 2014]
ohio_15 = ohio.loc[ohio['YYYY'] == 2015]
ohio_16 = ohio.loc[ohio['YYYY'] == 2016]
ohio_17 = ohio.loc[ohio['YYYY'] == 2017]

# %%
# Separate Virgnia by Year
virginia_10 = virginia.loc[virginia['YYYY'] == 2010]
virginia_11 = virginia.loc[virginia['YYYY'] == 2011]
virginia_12 = virginia.loc[virginia['YYYY'] == 2012]
virginia_13 = virginia.loc[virginia['YYYY'] == 2013]
virginia_14 = virginia.loc[virginia['YYYY'] == 2014]
virginia_15 = virginia.loc[virginia['YYYY'] == 2015]
virginia_16 = virginia.loc[virginia['YYYY'] == 2016]
virginia_17 = virginia.loc[virginia['YYYY'] == 2017]

# %%
# Separate Kentucky by Year
kentucky_10 = kentucky.loc[kentucky['YYYY'] == 2010]
kentucky_11 = kentucky.loc[kentucky['YYYY'] == 2011]
kentucky_12 = kentucky.loc[kentucky['YYYY'] == 2012]
kentucky_13 = kentucky.loc[kentucky['YYYY'] == 2013]
kentucky_14 = kentucky.loc[kentucky['YYYY'] == 2014]
kentucky_15 = kentucky.loc[kentucky['YYYY'] == 2015]
kentucky_16 = kentucky.loc[kentucky['YYYY'] == 2016]
kentucky_17 = kentucky.loc[kentucky['YYYY'] == 2017]

# %%
# Separate Pennsylvania by Year
pennsylvania_10 = pennsylvania.loc[pennsylvania['YYYY'] == 2010]
pennsylvania_11 = pennsylvania.loc[pennsylvania['YYYY'] == 2011]
pennsylvania_12 = pennsylvania.loc[pennsylvania['YYYY'] == 2012]
pennsylvania_13 = pennsylvania.loc[pennsylvania['YYYY'] == 2013]
pennsylvania_14 = pennsylvania.loc[pennsylvania['YYYY'] == 2014]
pennsylvania_15 = pennsylvania.loc[pennsylvania['YYYY'] == 2015]
pennsylvania_16 = pennsylvania.loc[pennsylvania['YYYY'] == 2016]
pennsylvania_17 = pennsylvania.loc[pennsylvania['YYYY'] == 2017]

# %%
# Separate West Virgnia by Year
west_virginia_10 = west_virginia.loc[west_virginia['YYYY'] == 2010]
west_virginia_11 = west_virginia.loc[west_virginia['YYYY'] == 2011]
west_virginia_12 = west_virginia.loc[west_virginia['YYYY'] == 2012]
west_virginia_13 = west_virginia.loc[west_virginia['YYYY'] == 2013]
west_virginia_14 = west_virginia.loc[west_virginia['YYYY'] == 2014]
west_virginia_15 = west_virginia.loc[west_virginia['YYYY'] == 2015]
west_virginia_16 = west_virginia.loc[west_virginia['YYYY'] == 2016]
west_virginia_17 = west_virginia.loc[west_virginia['YYYY'] == 2017]

# %%
# All Ohio Data
# Darker data points show higher data density
ohio.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)

# %%
# Ohio Cumulative Years Plot (2010-2017)

# Size = number of drug reports in state specific state/county
# Color = total drug reports in county
ohio.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=ohio["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
# Ohio Plot 2016
ohio_16.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=ohio_16["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
# Marker used for finding coordinates of worst counties
plt.annotate(xy=[-81.9,41.33], s="O")
plt.annotate(xy=[-84.75,39.1], s="O")

# Marker used for finding coordiantes of next-worst counties
plt.annotate(xy=[-83.2,40.05], s="X")
plt.annotate(xy=[-84.45,39.8], s="X")
plt.legend()

# %%
# Ohio Worst Counties in 2016
ohio_16 = ohio_16.to_numpy()
county1 = 0
county2 = 0
for i in range(len(ohio_16)):
    if ohio_16[i][10] < -84.4 and ohio_16[i][11] > 39.0 and ohio_16[i][11] < 39.4 and county1 == 0:
        print(ohio_16[i][2], ohio_16[i][1])
        county1 = 1
    elif ohio_16[i][10] < -81.7 and ohio_16[i][11] > 41.3 and ohio_16[i][11] < 41.4 and county2 == 0:
        print(ohio_16[i][2], ohio_16[i][1])
        county2 = 1
# Out:
# CUYAHOGA OH
# HAMILTON OH

# %%
# Ohio Next-Worst Counties in 2016
county1 = 0
county2 = 0
for i in range(len(ohio_16)):
    if ohio_16[i][10] < -83.1 and ohio_16[i][10] > -83.5 and ohio_16[i][11] > 39.9 and ohio_16[i][11] < 40.1 and county1 == 0:
        print(ohio_16[i][2], ohio_16[i][1])
        county1 = 1
    elif ohio_16[i][10] < -84.4 and ohio_16[i][10] > -84.5 and ohio_16[i][11] > 39.75 and ohio_16[i][11] < 39.85 and county2 == 0:
        print(ohio_16[i][2], ohio_16[i][1])
        county2 = 1
# Out:
# FRANKLIN OH
# MONTGOMERY OH

# %%
# All Virginia Data
# Darker data points show higher data density
virginia.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)

# %%
# Virginia Cumulative Years Plot (2010-2017)

# Size = number of drug reports in state specific state/county
# Color = total drug reports in county

virginia.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=virginia["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
# Virginia Plot 2016
virginia_16.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=virginia_16["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
# Marker used for finding coordinates of worst counties
plt.annotate(xy=[-77.54,38.83], s="O")

# Marker used for finding coordinates of next-worst counties
plt.annotate(xy=[-77.6,37.63], s="X")
plt.annotate(xy=[-77.7,37.4], s="X")
plt.legend()

# %%
# Virginia Worst Counties in 2016
#virginia_16 = virginia_16.to_numpy()
for i in range(len(virginia_16)):
    if virginia_16[i][10] < -77.5 and virginia_16[i][10] > -77.6 and virginia_16[i][11] > 38.7 and virginia_16[i][11] < 38.9:
        print(virginia_16[i][2], virginia_16[i][1])
        break
# Out:
# PRINCE WILLIAM VA

# %%
# Virgnia Next-Worst County in 2016
county1 = 0
county2 = 0
for i in range(len(virginia_16)):
    if virginia_16[i][10] < -77.6 and virginia_16[i][10] > -77.8 and virginia_16[i][11] > 37.3 and virginia_16[i][11] < 37.5 and county1 == 0:
        print(virginia_16[i][2], virginia_16[i][1])
        county1 = 1
    elif virginia_16[i][10] < -77.4 and virginia_16[i][10] > -77.8 and virginia_16[i][11] > 37.57 and virginia_16[i][11] < 37.67 and county2 == 0:
        print(virginia_16[i][2], virginia_16[i][1])
        county2 = 1
# Out:
# CHESTERFIELD VA
# HENRICO VA

# %%
# All Kentucky Data
# Darker data points show higher data density
kentucky.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)

# %%
# Kentucky Cumulative Years Plot (2010-2017)

# Size = number of drug reports in state specific state/county
# Color = total drug reports in county

kentucky.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=kentucky["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
# Kentucky Plot 2016
kentucky_16.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=kentucky_16["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
# Marker used for finding coordinates of worst counties
plt.annotate(xy=[-85.47,38.25], s="O")

# Marker used for finding coordinates of next-worst counties
plt.annotate(xy=[-84.53,37.98], s="X")
plt.annotate(xy=[-84.6,39.05], s="X")
plt.legend()

# %%
# Kentucky Worst County in 2016
kentucky_16 = kentucky_16.to_numpy()
for i in range(len(kentucky_16)):
    if kentucky_16[i][10] < -85.4 and kentucky_16[i][10] > -85.8 and kentucky_16[i][11] > 38.1 and kentucky_16[i][11] < 38.4:
        print(kentucky_16[i][2], kentucky_16[i][1])
        break
# Out:
# JEFFERSON KY

# %%
# Kentucky Next-Worst Counties in 2016
county1 = 0
county2 = 0
for i in range(len(kentucky_16)):
    if kentucky_16[i][10] < -84.4 and kentucky_16[i][10] > -84.6 and kentucky_16[i][11] > 37.9 and kentucky_16[i][11] < 38.1 and county1 == 0:
        print(kentucky_16[i][2], kentucky_16[i][1])
        county1 = 1
    elif kentucky_16[i][10] < -84.4 and kentucky_16[i][10] > -85.5 and kentucky_16[i][11] > 39.05 and kentucky_16[i][11] < 39.1 and county2 == 0:
        print(kentucky_16[i][2], kentucky_16[i][1])
        county2 = 1
# Out:
# FAYETTE KY
# KENTON KY

# %%
# All Pennsylvania Data
# Darker data points show higher data density
pennsylvania.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)

# %%
# Pennsylvania Cumulative Years Plot (2010-2017)

# Size = number of drug reports in state specific state/county
# Color = total drug reports in county

pennsylvania.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=pennsylvania["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
# Pennsylvania Plot 2016
pennsylvania_16.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=pennsylvania_16["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
# Marker used for finding coordinates of worst counties
plt.annotate(xy=[-75.05,40.1], s="O")

# Marker used for finding coordinates of next-worst counties
plt.annotate(xy=[-79.95,40.62], s="X")
plt.legend()

# %%
# Pennsylavnia Worst County in 2016
pennsylvania_16 = pennsylvania_16.to_numpy()
for i in range(len(pennsylvania_16)):
    if pennsylvania_16[i][10] < -74.9 and pennsylvania_16[i][10] > -75.2 and pennsylvania_16[i][11] > 39.9 and pennsylvania_16[i][11] < 40.3:
        print(pennsylvania_16[i][2], pennsylvania_16[i][1])
        break
# Out:
# PHILADELPHIA PA

# %%
# Pennsylavnia Next-Worst County in 2016
for i in range(len(pennsylvania_16)):
    if pennsylvania_16[i][10] < -79.8 and pennsylvania_16[i][10] > -80.1 and pennsylvania_16[i][11] > 40.5 and pennsylvania_16[i][11] < 40.7:
        print(pennsylvania_16[i][2], pennsylvania_16[i][1])
        break
# Out:
# ALLEGHENY PA

# %%
# All West Virginia Data
# Darker data points show higher data density
west_virginia.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.1)

# %%
# West Virginia Cumulative Years Plot (2010-2017)

# Size = number of drug reports in state specific state/county
# Color = total drug reports in county

west_virginia.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=west_virginia["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
# West Virginia Plot 2016
west_virginia_16.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.4,
    s=west_virginia_16["DrugReports"], label="Drug Reports", figsize=(10,7),
    c="TotalDrugReportsCounty", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
# Marker used for finding coordinates of worst counties
plt.annotate(xy=[-81.84,38.23], s="O")

# Marker used for finding coordinates of next-worst counties
plt.annotate(xy=[-80.38,39.24], s="X")
plt.annotate(xy=[-81.58,39.23], s="X")
plt.legend()

# %%
# West Virginia Worst County in 2016
west_virginia_16 = west_virginia_16.to_numpy()
for i in range(len(west_virginia_16)):
    if west_virginia_16[i][10] < -81.7 and west_virginia_16[i][10] > -82 and west_virginia_16[i][11] > 38.22 and west_virginia_16[i][11] < 38.3:
        print(west_virginia_16[i][2], west_virginia_16[i][1])
        break
# Out:
# KANAWHA WV

# %%
# West Virginia Next-Worst Counties 2016
county1 = 0
county2 = 0
for i in range(len(west_virginia_16)):
    if west_virginia_16[i][10] < -80.3 and west_virginia_16[i][10] > -80.43 and west_virginia_16[i][11] > 39.15 and west_virginia_16[i][11] < 39.3 and county1 == 0:
        print(west_virginia_16[i][2], west_virginia_16[i][1])
        county1 = 1
    elif west_virginia_16[i][10] < -81.5 and west_virginia_16[i][10] > -81.6 and west_virginia_16[i][11] > 39.15 and west_virginia_16[i][11] < 39.3 and county2 == 0:
        print(west_virginia_16[i][2], west_virginia_16[i][1])
        county2 = 1
# Out:
# HARRISON WV
# WOOD WV
